# %% [markdown]
# # Project: Investigating Sales Dataset
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset
#
# The dataset used is a CSV file called sales_data.csv. It contains information about sales made by a fictional company over the course of a year. The columns in the dataset are as follows:
#
# - `date`: The date of the sale (in YYYY-MM-DD format)
# - `product`: The name of the product sold
# - `category`: The category of the product (e.g. "electronics", "clothing", etc.)
# - `price`: The price of the product (in USD)
# - `quantity`: The quantity of the product sold
# - `revenue`: The total revenue generated by the sale (i.e. price * quantity)

# %%
import pandas as pd

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# ### General Properties

# %%
sales_data_df = pd.read_csv('sales_data.csv')
sales_data_df.head(10)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# ### Research Question 1
#
# #### What was the total revenue generated by the company over the course of the year?

# %% [markdown]
# ### Research Question 2
#
# #### Which product had the highest revenue? How much revenue did it generate?

# %% [markdown]
# ### Research Question 3
#
# #### What was the average price of a product sold by the company?

# %% [markdown]
# ### Research Question 4
#
# #### What was the total quantity of products sold by the company?

# %% [markdown]
# ### Research Question 5
#
# #### Which category had the highest revenue? How much revenue did it generate?

# %% [markdown]
# ### Research Question 6
#
# #### What was the average revenue per sale?

# %% [markdown]
# ### Research Question 7
#
# #### What was the total revenue generated in each quarter of the year? (i.e. Q1, Q2, Q3, Q4)

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
